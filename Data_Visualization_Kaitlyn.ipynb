# %% [markdown]
# <a href="https://colab.research.google.com/github/FLC-ML/raman-id/blob/master/Data_Visualization_Kaitlyn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Import Libraries

# %%
# import packages
import tensorflow as tf
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sns
import numpy as np

# %% [markdown]
# Load Data

# %%
# load data (specific to google drive)
X_test = np.load('/content/drive/My Drive/ML Group/Datasets/data/X_test.npy')
y_test = np.load('/content/drive/My Drive/ML Group/Datasets/data/y_test.npy')

X = np.load('/content/drive/My Drive/ML Group/Datasets/data/X_reference.npy')
y = np.load('/content/drive/My Drive/ML Group/Datasets/data/y_reference.npy')

X_fine = np.load('/content/drive/My Drive/ML Group/Datasets/data/X_finetune.npy')
y_fine = np.load('/content/drive/My Drive/ML Group/Datasets/data/y_finetune.npy')

print("X Reference Dataset Shape: ", X.shape)
print("y Reference Dataset Shape: ", y.shape)
print("X Test Dataset Shape: ", X_test.shape)
print("y Test Dataset Shape: ", y_test.shape)
print("X Finetuning Dataset Shape: ", X_fine.shape)
print("y Finetuning Dataset Shape: ", y_fine.shape)

# %% [markdown]
# Plot Signals

# %%
C_glabrata = np.where(y==29)
C_albicans = np.where(y==28)
P_aeruginosa_2 = np.where(y==27)
P_aeruginosa_1 = np.where(y==26)
S_enterica = np.where(y==25)
S_marcescens = np.where(y==24)
P_mirabilis = np.where(y==23)
E_cloacae = np.where(y==22)
K_aerongenes = np.where(y==21)
K_pneumoniae_2 = np.where(y==20)
K_pneumoniae_1 = np.where(y==19)
E_coli_2 = np.where(y==18)
E_coli_1 = np.where(y==17)
E_faecium = np.where(y==16)
E_faecalis_2 = np.where(y==15)
E_faecalis_1 = np.where(y==14)
S_sanguinis = np.where(y==13)
Group_G_Strep = np.where(y==12)
Group_C_Strep = np.where(y==11)
Group_B_Strep = np.where(y==10)
Group_A_Strep = np.where(y==9)
S_pneumoniae_2 = np.where(y==8)
S_pneumoniae_1 = np.where(y==7)
S_lugdunensis = np.where(y==6)
S_epidermindis = np.where(y==5)
MSSA_3 = np.where(y==4)
MSSA_2 = np.where(y==3)
MSSA_1 = np.where(y==2)
MRSA_2 = np.where(y==1)
MRSA_1_iso = np.where(y==0)


plt.figure(figsize = (8,2))
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[1], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[2], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[3], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[4], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[5], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[6], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[7], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[8], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[9], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[0], color = '#008080', linewidth = 0.5, label = 'C. albicans')
plt.legend()
plt.tight_layout()
plt.savefig("C. albicans.png")

plt.figure(figsize = (8,2))
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[2001], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[2002], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[2003], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[2004], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[2005], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[2006], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[2007], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[2008], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[2009], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[2000], color = '#008080', linewidth = 0.5, label = 'C glabrata')
plt.legend()
plt.savefig("C. glabrata.png")
 
plt.figure(figsize = (8,2))
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[4001], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[4002], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[4003], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[4004], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[4005], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[4006], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[4007], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[4008], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[4009], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[4000], color = '#008080', linewidth = 0.5, label = 'K. aerogenes')
plt.legend()
plt.savefig("K. aerogenes.png")
 
plt.figure(figsize = (8,2))
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[6001], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[6002], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[6003], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[6004], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[6005], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[6006], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[6007], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[6008], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[6009], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[6000], color = '#008080', linewidth = 0.5, label = 'E. coli 1')
plt.legend()
plt.savefig("E. coli 1.png")
 
plt.figure(figsize = (8,2))
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[8001], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[8002], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[8003], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[8004], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[8005], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[8006], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[8007], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[8008], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[8009], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[8000], color = '#008080', linewidth = 0.5, label = 'E. coli 2')
plt.legend()
plt.savefig("E. coli 2.png")
 
plt.figure(figsize = (8,2))
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[10001], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[10002], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[10003], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[10004], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[10005], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[10006], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[10007], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[10008], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[10009], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[10000], color = '#008080', linewidth = 0.5, label = '"E. faecium')
plt.legend()
plt.savefig("E. faecium.png")
 
plt.figure(figsize = (8,2))
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[12001], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[12002], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[12003], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[12004], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[12005], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[12006], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[12007], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[12008], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[12009], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[12000], color = '#008080', linewidth = 0.5, label = 'E. faecalis 1')
plt.legend()
plt.savefig("E. faecalis 1.png")
 
plt.figure(figsize = (8,2))
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[14001], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[14002], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[14003], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[14004], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[14005], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[14006], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[14007], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[14008], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[14009], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[14000], color = '#008080', linewidth = 0.5, label = 'E. faecalis 2')
plt.legend()
plt.savefig("E. faecalis 2.png")
 
plt.figure(figsize = (8,2))
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[16001], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[16002], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[16003], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[16004], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[16005], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[16006], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[16007], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[16008], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[16009], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[16000], color = '#008080', linewidth = 0.5, label = 'E. cloacae')
plt.legend()
plt.savefig("E. cloacae.png")
 
plt.figure(figsize = (8,2))
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[18001], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[18002], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[18003], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[18004], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[18005], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[18006], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[18007], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[18008], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[18009], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[18000], color = '#008080', linewidth = 0.5, label = '')
plt.legend()
plt.savefig("K. pneumoniae 1.png")
 
plt.figure(figsize = (8,2))
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[20001], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[20002], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[20003], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[20004], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[20005], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[20006], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[20007], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[20008], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[20009], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[20000], color = '#008080', linewidth = 0.5, label = 'K. pneumoniae 2')
plt.legend()
plt.savefig("K. pneumoniae 2.png")
 
plt.figure(figsize = (8,2))
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[22001], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[22002], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[22003], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[22004], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[22005], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[22006], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[22007], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[22008], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[22009], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[22000], color = '#008080', linewidth = 0.5, label = 'P. mirabilis')
plt.legend()
plt.savefig("P. mirabilis.png")
 
plt.figure(figsize = (8,2))
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[24001], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[24002], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[24003], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[24004], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[24005], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[24006], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[24007], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[24008], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[24009], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[24000], color = '#008080', linewidth = 0.5, label = 'P. aeruginosa 1')
plt.legend()
plt.savefig("P. aeruginosa 1.png")
 
plt.figure(figsize = (8,2))
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[26001], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[26002], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[26003], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[26004], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[26005], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[26006], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[26007], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[26008], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[26009], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[26010], color = '#008080', linewidth = 0.5, label = 'P. aeruginosa 2')
plt.legend()
plt.savefig("P. aeruginosa 2.png")
 
plt.figure(figsize = (8,2))
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[28001], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[28002], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[28003], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[28004], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[28005], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[28006], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[28007], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[28008], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[28009], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[28000], color = '#008080', linewidth = 0.5, label = 'MSSA 1')
plt.legend()
plt.savefig("MSSA 1.png")
 
plt.figure(figsize = (8,2))
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[30001], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[30002], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[30003], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[30004], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[30005], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[30006], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[30007], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[30008], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[30009], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[30000], color = '#008080', linewidth = 0.5, label = 'MSSA 3')
plt.legend()
plt.savefig("MSSA 3.png")
 
plt.figure(figsize = (8,2))
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[32001], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[32002], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[32003], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[32004], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[32005], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[32006], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[32007], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[32008], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[32009], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[32000], color = '#008080', linewidth = 0.5, label = 'MRSA 1')
plt.legend()
plt.savefig("MRSA 1.png")
 
plt.figure(figsize = (8,2))
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[34001], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[34002], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[34003], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[34004], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[34005], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[34006], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[34007], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[34008], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[34009], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[34000], color = '#008080', linewidth = 0.5, label = 'MRSA 2')
plt.legend()
plt.savefig("MRSA 2.png")
 
plt.figure(figsize = (8,2))
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[36001], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[36002], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[36003], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[36004], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[36005], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[36006], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[36007], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[36008], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[36009], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[36000], color = '#008080', linewidth = 0.5, label = 'MSSA 2')
plt.legend()
plt.savefig("MSSA 2.png")
 
plt.figure(figsize = (8,2))
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[38001], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[38002], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[38003], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[38004], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[38005], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[38006], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[38007], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[38008], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[38009], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[38000], color = '#008080', linewidth = 0.5, label = 'S. enterica')
plt.legend()
plt.savefig("S. enterica.png")
 
plt.figure(figsize = (8,2))
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[40001], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[40002], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[40003], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[40004], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[40005], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[40006], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[40007], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[40008], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[40009], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[40000], color = '#008080', linewidth = 0.5, label = 'S. epidermidis')
plt.legend()
plt.savefig("S. epidermidis.png")
 
plt.figure(figsize = (8,2))
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[42001], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[42002], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[42003], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[42004], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[42005], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[42006], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[42007], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[42008], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[42009], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[42000], color = '#008080', linewidth = 0.5, label = 'S. lugdunensis')
plt.legend()
plt.savefig("S. lugdunensis.png")
 
plt.figure(figsize = (8,2))
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[44001], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[44002], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[44003], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[44004], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[44005], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[44006], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[44007], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[44008], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[44009], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[44000], color = '#008080', linewidth = 0.5, label = 'S. marcescens')
plt.legend()
plt.savefig("S. marcescens.png")
 
plt.figure(figsize = (8,2))
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[46001], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[46002], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[46003], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[46004], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[46005], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[46006], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[46007], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[46008], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[46009], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[46000], color = '#008080', linewidth = 0.5, label = 'S. pneumoniae 2')
plt.legend()
plt.savefig("S. pneumoniae 2.png")
 
plt.figure(figsize = (8,2))
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[48001], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[48002], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[48003], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[48004], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[48005], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[48006], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[48007], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[48008], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[48009], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[48000], color = '#008080', linewidth = 0.5, label = 'S. pneumoniae 1')
plt.legend()
plt.savefig("S. pneumoniae 1.png")
 
plt.figure(figsize = (8,2))
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[50001], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[50002], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[50003], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[50004], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[50005], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[50006], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[50007], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[50008], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[50009], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[50000], color = '#008080', linewidth = 0.5, label = 'S. sanguinis')
plt.legend()
plt.savefig("S. sanguinis.png")
 
plt.figure(figsize = (8,2))
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[52001], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[52002], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[52003], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[52004], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[52005], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[52006], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[52007], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[52008], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[52009], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[52000], color = '#008080', linewidth = 0.5, label = 'Group A Strep.')
plt.legend()
plt.savefig("Group A Strep.png")
 
plt.figure(figsize = (8,2))
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[54001], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[54002], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[54003], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[54004], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[54005], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[54006], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[54007], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[54008], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[54009], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[54000], color = '#008080', linewidth = 0.5, label = 'Group B Strep.')
plt.legend()
plt.savefig("Group B Strep.png")
 
plt.figure(figsize = (8,2))
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[56001], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[56002], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[56003], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[56004], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[56005], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[56006], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[56007], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[56008], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[56009], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[56000], color = '#008080', linewidth = 0.5, label = 'Group C Strep.')
plt.legend()
plt.savefig("Group C Strep.png")
 
plt.figure(figsize = (8,2))
plt.xlabel('Wavenumber [$cm^{-1}$]')
plt.ylabel('Intensity')
plt.plot(X[58001], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[58002], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[58003], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[58004], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[58005], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[58006], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[58007], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[58008], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[58009], color = 'grey', linewidth = 0.2, alpha = 0.5)
plt.plot(X[58000], color = '#008080', linewidth = 0.5, label = 'Group G Strep.')
plt.legend()
plt.savefig("Group G Strep.png")

# %% [markdown]
# Signal Subplot

# %%
fig, axs = plt.subplots(30, sharex = True, sharey = True, figsize=(8, 20), tight_layout=True)
fig.suptitle('Bacterial Signals', y = 1.0025)
fig.text(.55,0,'Wavenumber [$cm^{-1}$]', ha = 'center')
fig.text(0,.55,'Intensity', va = 'center', rotation = 'vertical')

axs[0].plot(X[0], color = '#003f5c', linewidth = 0.5, label = 'C. albicans')
axs[0].legend(frameon = False, loc = "upper right")
axs[1].plot(X[2000], color = '#444e86', linewidth = 0.5, label = 'C glabrata')
axs[1].legend(frameon = False, loc = "upper right")
axs[2].plot(X[4000], color = '#955196', linewidth = 0.5, label = 'K. aerogenes')
axs[2].legend(frameon = False, loc = "upper right")
axs[3].plot(X[6000], color = '#dd5182', linewidth = 0.5, label = 'E. coli 1')
axs[3].legend(frameon = False, loc = "upper right")
axs[4].plot(X[8000], color = '#ff6e54', linewidth = 0.5, label = 'E. coli 2')
axs[4].legend(frameon = False, loc = "upper right")
axs[5].plot(X[10000], color = '#ffa600', linewidth = 0.5, label = '"E. faecium')
axs[5].legend(frameon = False, loc = "upper right")
axs[6].plot(X[12000], color = '#003f5c', linewidth = 0.5, label = 'E. faecalis 1')
axs[6].legend(frameon = False, loc = "upper right")
axs[7].plot(X[14000], color = '#444e86', linewidth = 0.5, label = 'E. faecalis 2')
axs[7].legend(frameon = False, loc = "upper right")
axs[8].plot(X[16000], color = '#955196', linewidth = 0.5, label = 'E. cloacae')
axs[8].legend(frameon = False, loc = "upper right")
axs[9].plot(X[18000], color = '#dd5182', linewidth = 0.5, label = 'K. pneumoniae')
axs[9].legend(frameon = False, loc = "upper right")
axs[10].plot(X[20000], color = '#ff6e54', linewidth = 0.5, label = 'K. pneumoniae 2')
axs[10].legend(frameon = False, loc = "upper right")
axs[11].plot(X[22000], color = '#ffa600', linewidth = 0.5, label = 'P. mirabilis')
axs[11].legend(frameon = False, loc = "upper right")
axs[12].plot(X[24000], color = '#003f5c', linewidth = 0.5, label = 'P. aeruginosa 1')
axs[12].legend(frameon = False, loc = "upper right")
axs[13].plot(X[26000], color = '#444e86', linewidth = 0.5, label = 'P. aeruginosa 2')
axs[13].legend(frameon = False, loc = "upper right")
axs[14].plot(X[28000], color = '#955196', linewidth = 0.5, label = 'MSSA 1')
axs[14].legend(frameon = False, loc = "upper right")
axs[15].plot(X[30000], color = '#dd5182', linewidth = 0.5, label = 'MSSA 3')
axs[15].legend(frameon = False, loc = "upper right")
axs[16].plot(X[32000], color = '#ff6e54', linewidth = 0.5, label = 'MRSA 1')
axs[16].legend(frameon = False, loc = "upper right")
axs[17].plot(X[34000], color = '#ffa600', linewidth = 0.5, label = 'MRSA 2')
axs[17].legend(frameon = False, loc = "upper right")
axs[18].plot(X[36000], color = '#003f5c', linewidth = 0.5, label = 'MSSA 2')
axs[18].legend(frameon = False, loc = "upper right")
axs[19].plot(X[38000], color = '#444e86', linewidth = 0.5, label = 'S. enterica')
axs[19].legend(frameon = False, loc = "upper right")
axs[20].plot(X[40000], color = '#955196', linewidth = 0.5, label = 'S. epidermidis')
axs[20].legend(frameon = False, loc = "upper right")
axs[21].plot(X[42000], color = '#dd5182', linewidth = 0.5, label = 'S. lugdunensis')
axs[21].legend(frameon = False, loc = "upper right")
axs[22].plot(X[44000], color = '#ff6e54', linewidth = 0.5, label = 'S. marcescens')
axs[22].legend(frameon = False, loc = "upper right")
axs[23].plot(X[46000], color = '#ffa600', linewidth = 0.5, label = 'S. pneumoniae 2')
axs[23].legend(frameon = False, loc = "upper right")
axs[24].plot(X[48000], color = '#003f5c', linewidth = 0.5, label = 'S. pneumoniae 1')
axs[24].legend(frameon = False, loc = "upper right")
axs[25].plot(X[50000], color = '#444e86', linewidth = 0.5, label = 'S. sanguinis')
axs[25].legend(frameon = False, loc = "upper right")
axs[26].plot(X[52000], color = '#955196', linewidth = 0.25,label = 'Group A Strep.')
axs[26].legend(frameon = False, loc = "upper right")
axs[27].plot(X[54000], color = '#dd5182', linewidth = 0.25,label = 'Group B Strep.')
axs[27].legend(frameon = False, loc = "upper right")
axs[28].plot(X[56000], color = '#ff6e54', linewidth = 0.25,label = 'Group C Strep.')
axs[28].legend(frameon = False, loc = "upper right")
axs[29].plot(X[58000], color = '#ffa600', linewidth = 0.25,label = 'Group G Strep.')
axs[29].legend(frameon = False, loc = "upper right")

fig.savefig('Signal Subplot')

# %% [markdown]
# Signal Subplots: Least Accurate Identifications

# %%
# MRSA 1 and MSSA 3

fig, axs = plt.subplots(2, sharex = True, sharey = True, figsize=(8, 2), tight_layout=True)
fig.suptitle('MRSA 1 and MSSA 3 Signal Comparison', y = 1.005)
fig.text(.55,0,'Wavenumber [$cm^{-1}$]', ha = 'center')
fig.text(0,.55,'Intensity', va = 'center', rotation = 'vertical')

axs[0].plot(X[30000], color = '#ffa600', linewidth = 0.5, label = 'MSSA 3')
axs[0].legend(frameon = False, loc = "upper right")
axs[1].plot(X[32000], color = '#dd5182', linewidth = 0.5, label = 'MRSA 1')
axs[1].legend(frameon = False, loc = "upper right")

fig.savefig('MRSA 1 and MSSA 3')

# %%
# S. lugdunensis and MRSA 2

fig, axs = plt.subplots(2, sharex = True, sharey = True, figsize=(8, 2), tight_layout=True)
fig.suptitle('S. lugdunensis and MRSA 2 Signal Comparison', y = 1.0025)
fig.text(.55,0,'Wavenumber [$cm^{-1}$]', ha = 'center')
fig.text(0,.55,'Intensity', va = 'center', rotation = 'vertical')

axs[0].plot(X[34000], color = '#ffa600', linewidth = 0.5, label = 'MRSA 2')
axs[0].legend(frameon = False, loc = "upper right")
axs[1].plot(X[42000], color = '#dd5182', linewidth = 0.5, label = 'S. lugdunensis')
axs[1].legend(frameon = False, loc = "upper right")

fig.savefig('S. lugdunensis and MRSA 2.png')

# %%
# S. pneumoniae 1 and S. pneumoniae 2
fig, axs = plt.subplots(2, sharex = True, sharey = True, figsize=(8, 2), tight_layout=True)
fig.suptitle('S. pneumoniae 1 and S. pneumoniae 2 Signal Comparison', y = 1.0025)
fig.text(.55,0,'Wavenumber [$cm^{-1}$]', ha = 'center')
fig.text(0,.55,'Intensity', va = 'center', rotation = 'vertical')

axs[0].plot(X[46000], color = '#ffa600', linewidth = 0.5, label = 'S. pneumoniae 2')
axs[0].legend(frameon = False, loc = "upper right")
axs[1].plot(X[48000], color = '#dd5182', linewidth = 0.5, label = 'S. pneumoniae 1')
axs[1].legend(frameon = False, loc = "upper right")

fig.savefig('S. pneumoniae 1 and S. pneumoniae 2.png')

# %%
# Group G Strep. and Group A Strep.
fig, axs = plt.subplots(2, sharex = True, sharey = True, figsize=(8, 2), tight_layout=True)
fig.suptitle('Group G Strep. and Group A Strep. Signal Comparison', y = 1.0025)
fig.text(.55,0,'Wavenumber [$cm^{-1}$]', ha = 'center')
fig.text(0,.55,'Intensity', va = 'center', rotation = 'vertical')

axs[0].plot(X[52000], color = '#ffa600', linewidth = 0.25,label = 'Group A Strep.')
axs[0].legend(frameon = False, loc = "upper right")
axs[1].plot(X[58000], color = '#dd5182', linewidth = 0.25,label = 'Group G Strep.')
axs[1].legend(frameon = False, loc = "upper right")

fig.savefig('Group G Strep. and Group A Strep.png')

# %%
# K. pneumoniae 1 and E. cloacae, Group C Strep., S. enterica
fig, axs = plt.subplots(4, sharex = True, sharey = True, figsize=(8, 4), tight_layout=True)
fig.suptitle('K. pneumoniae 1 and E. cloacae, Group C Strep., S. enterica Signal Comparison', y = 1.0025)
fig.text(.55,0,'Wavenumber [$cm^{-1}$]', ha = 'center')
fig.text(0,.55,'Intensity', va = 'center', rotation = 'vertical')

axs[0].plot(X[16000], color = '#955196', linewidth = 0.5, label = 'E. cloacae')
axs[0].legend(frameon = False, loc = "upper right")
axs[1].plot(X[18000], color = '#dd5182', linewidth = 0.5, label = 'K. pneumoniae')
axs[1].legend(frameon = False, loc = "upper right")
axs[2].plot(X[38000], color = '#444e86', linewidth = 0.5, label = 'S. enterica')
axs[2].legend(frameon = False, loc = "upper right")
axs[3].plot(X[56000], color = '#ff6e54', linewidth = 0.25,label = 'Group C Strep.')
axs[3].legend(frameon = False, loc = "upper right")

fig.savefig('K. pneumoniae 1 and E. cloacae, Group C Strep., S. enterica.png')

# %%
# P. aeruginosa 2 and P. aeruginosa 1
fig, axs = plt.subplots(2, sharex = True, sharey = True, figsize=(8, 2), tight_layout=True)
fig.suptitle('P. aeruginosa 2 and P. aeruginosa 1 Signal Comparison', y = 1.0025)
fig.text(.55,0,'Wavenumber [$cm^{-1}$]', ha = 'center')
fig.text(0,.55,'Intensity', va = 'center', rotation = 'vertical')

axs[0].plot(X[24011], color = '#ffa600', linewidth = 0.5, label = 'P. aeruginosa 1')
axs[0].legend(frameon = False, loc = "upper right")
axs[1].plot(X[26001], color = '#dd5182', linewidth = 0.5, label = 'P. aeruginosa 2')
axs[1].legend(frameon = False, loc = "upper right")

fig.savefig('P. aeruginosa 2 and P. aeruginosa 1.png')

# %%
# C. glabrata and E. faecium
fig, axs = plt.subplots(2, sharex = True, sharey = True, figsize=(8, 2), tight_layout=True)
fig.suptitle('C. glabrata and E. faecium Signal Comparison', y = 1.0025)
fig.text(.55,0,'Wavenumber [$cm^{-1}$]', ha = 'center')
fig.text(0,.55,'Intensity', va = 'center', rotation = 'vertical')

axs[0].plot(X[2015], color = '#444e86', linewidth = 0.5, label = 'C glabrata')
axs[0].legend(frameon = False, loc = "upper right")
axs[1].plot(X[10020], color = '#ffa600', linewidth = 0.5, label = '"E. faecium')
axs[1].legend(frameon = False, loc = "upper right")

fig.savefig('C. glabrata and E. faecium.png')
