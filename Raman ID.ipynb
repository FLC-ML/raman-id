# %% [markdown]
# <a href="https://colab.research.google.com/github/FLC-ML/raman-id/blob/master/Raman%20ID.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# Imports/ResNet Class

# %%
# import packages
import tensorflow as tf
from tensorflow.keras.layers import BatchNormalization, ZeroPadding1D, Conv1D, AveragePooling1D, MaxPooling1D
from tensorflow.keras.layers import Activation, Dense,  Flatten, Input, add, Dropout
from tensorflow.keras.regularizers import l2
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow import summary
from sklearn.model_selection import train_test_split
import numpy as np



#define resnet class
class ResNet:
  @staticmethod
  #create one residual block
  def residual_module(data, K, convLayers, chanDim=-1, reduce=False, reg=0.0001, bnEps=2e-5, bnMom=0.9, dropout=0.8, kernel_size=1):
    K = K*0.25
    shortcut = data
    x = data

    print("Resnet Block")
    for i in range(convLayers):
      x = BatchNormalization(axis=chanDim, epsilon=bnEps, momentum=bnMom)(x)
      x = Activation("relu")(x)
      
      if (i == convLayers - 1):
        K = K*4
        x = Conv1D(int(K), kernel_size, use_bias=False, kernel_regularizer=l2(reg))(x)
      elif (i == int(convLayers/2)):
        x = Conv1D(int(K), kernel_size, use_bias=False, kernel_regularizer=l2(reg))(x)
      else:
        x = Conv1D(int(K), kernel_size, use_bias=False, kernel_regularizer=l2(reg))(x)
      if (dropout is not None):
        x = Dropout(dropout)(x)
     
      #print("**PostConvolution", x.shape)
      print("*ConvGroup", x.shape, K)

    if reduce:
      #shortcut = BatchNormalization(axis=chanDim, epsilon=bnEps, momentum=bnMom)(shortcut)
      shortcut = Conv1D(K, kernel_size, use_bias=False, kernel_regularizer=l2(reg))(shortcut)
    print("*Shortcut shape", shortcut.shape)

    x = add([x, shortcut])

    return x

  @staticmethod
  #build a model out of resblocks
  def build(inputShape, resLayers, classes, convLayers, filters, reg=0.0001, bnEps=2e-5, bnMom=0.9, dropout=None, kernel_size=1):
    chanDim = -1
    inputs = Input(shape=inputShape)

    #initial batchnorm and convolutional layer
    x = BatchNormalization(axis=chanDim, epsilon = bnEps, momentum=bnMom)(inputs)
    x = Conv1D(filters[0], 5, strides=2, use_bias=False, padding="same", kernel_regularizer=l2(reg))(inputs)
    
    x = BatchNormalization(axis=chanDim, epsilon=bnEps, momentum=bnMom)(x)
    x = Activation("relu")(x)

       
    x = ResNet.residual_module(data=x, K=filters[1], convLayers=convLayers, reduce=True, bnEps=bnEps, bnMom=bnMom)

    for i in range(0, resLayers - 1):
      x = ResNet.residual_module(data=x, K=filters[1], convLayers=convLayers, bnEps=bnEps, bnMom=bnMom)
    
    x = BatchNormalization(axis=chanDim, epsilon=bnEps, momentum=bnMom)(x)
    x = Activation("relu")(x)
    x = AveragePooling1D(8)(x)
    x = Flatten()(x)
    x = Dense(classes, kernel_regularizer=l2(reg))(x)
    x = Activation("softmax")(x)

    model = Model(inputs, x, name="resnet")

    return model

  @staticmethod
  def pretrain(save_directory, features, labels, verbose=1,
                                   batch_size=32, 
                                   epochs=10, 
                                   filters=(64, 100), 
                                   resLayers=1, 
                                   convLayers=1, 
                                   learningRate=0.1,
                                   dropout=0.8,
                                   kernel_size=1):
    X = features
    y = labels

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.01)


    #add depth channel
    X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
    X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

    #input shape is everything except for the number of samples 
    #number of classes is the number of unique items in y
    in_shape = X_train.shape[1:]
    n_classes = len(np.unique(y_train))

    #build model
    model = ResNet.build(inputShape=in_shape, classes=n_classes, convLayers=convLayers, resLayers=resLayers, filters=filters, dropout=dropout)

    #compile, train model
    model.compile(loss = 'sparse_categorical_crossentropy', optimizer=Adam(learningRate), metrics = ['accuracy'])
    
    model.summary()
    
    model.fit(X_train, y_train, batch_size=batch_size,epochs=epochs, verbose=verbose)

    #test accuracy
    accuracy = model.evaluate(X_test, y_test, batch_size=batch_size, verbose=verbose)
    print("(pretraining) Testing accuracy from within X_reference.npy and y_reference.npy:", accuracy[1])

    # Save the weights
    model.save(save_directory)

    #return model
    return model

  @staticmethod
  def finetune(save_directory, features, labels, verbose=1,
               learningRate=1e-5, 
               batch_size=10, 
               epochs=10):
    X = features
    y = labels

    #create 
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

    X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
    X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))
    
    
    model = load_model(save_directory)
  
    model.compile(optimizer=Adam(learningRate),  # Very low learning rate
    loss = 'sparse_categorical_crossentropy', metrics=['accuracy'])

    model.summary()

    model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, verbose=verbose)
    loss, acc = model.evaluate(X_test, y_test, batch_size=batch_size, verbose=verbose)
    print("(finetuning) Testing accuracy from within X_fine and y_fine: ", acc)
  
    return model

# %% [markdown]
# Pretraining Hyperparameters and Train/Test

# %%
#pretrain hyperparameters
batch_size = 100
epochs = 10
verbose = 1
filters = (64, 100)
resLayers = 1
convLayers = 1
learningRate = 0.001
dropout = 0.8
kernel_size = 1


#save_directory is the path where the model will be saved after pretraining 
#and the path where the finetuning model will read from
save_directory = '/content/drive/My Drive/ML Group/Individual Work/Denzel/Saved Models/base.h5' 


#load data (specific to google drive)
X_test = np.load('/content/drive/My Drive/ML Group/Datasets/data/X_test.npy')
y_test = np.load('/content/drive/My Drive/ML Group/Datasets/data/y_test.npy')

X = np.load('/content/drive/My Drive/ML Group/Datasets/data/X_reference.npy')
y = np.load('/content/drive/My Drive/ML Group/Datasets/data/y_reference.npy')

X_fine = np.load('/content/drive/My Drive/ML Group/Datasets/data/X_finetune.npy')
y_fine = np.load('/content/drive/My Drive/ML Group/Datasets/data/y_finetune.npy')

indices = np.arange(X.shape[0])
np.random.shuffle(indices)

X = X[indices]
y = y[indices]

pretrained_model = ResNet.pretrain(save_directory=save_directory, features=X, labels=y, verbose=verbose,
                                   batch_size=batch_size, 
                                   epochs=epochs, 
                                   filters=filters, 
                                   resLayers=resLayers, 
                                   convLayers=convLayers, 
                                   learningRate=learningRate,
                                   dropout=dropout,
                                   kernel_size=kernel_size)

pre_loss, pre_acc = pretrained_model.evaluate(X_test, y_test, batch_size=batch_size, verbose=verbose)
print("Testing loss, accuracy after pretraining from X_test and y_test:", pre_loss, pre_acc)
# Out:
# Resnet Block
# *ConvGroup (None, 500, 100) 100.0
# *Shortcut shape (None, 500, 100)
# Model: "resnet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 1000, 1)]    0
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 500, 64)      320         input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 500, 64)      256         conv1d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 500, 64)      0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 500, 64)      256         activation_6[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 500, 64)      0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 500, 100)     6400        activation_7[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 500, 100)     0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 500, 100)     6400        activation_6[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 500, 100)     0           dropout_2[0][0]
#                                                                  conv1d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 500, 100)     400         add_2[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 500, 100)     0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_1 (AveragePoo (None, 62, 100)      0           activation_8[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 6200)         0           average_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 30)           186030      flatten_1[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 30)           0           dense_1[0][0]
# ==================================================================================================
# Total params: 200,062
# Trainable params: 199,606
# Non-trainable params: 456
# __________________________________________________________________________________________________
# Epoch 1/10
# 594/594 [==============================] - 6s 9ms/step - loss: 0.5634 - accuracy: 0.8426
# Epoch 2/10
# 594/594 [==============================] - 6s 9ms/step - loss: 0.2816 - accuracy: 0.9169
# Epoch 3/10
# 594/594 [==============================] - 6s 9ms/step - loss: 0.2639 - accuracy: 0.9232
# Epoch 4/10
# 594/594 [==============================] - 6s 9ms/step - loss: 0.2453 - accuracy: 0.9293
# Epoch 5/10
# 594/594 [==============================] - 6s 9ms/step - loss: 0.2421 - accuracy: 0.9297
# Epoch 6/10
# 594/594 [==============================] - 6s 9ms/step - loss: 0.2334 - accuracy: 0.9347
# Epoch 7/10
# 594/594 [==============================] - 6s 9ms/step - loss: 0.2269 - accuracy: 0.9364
# Epoch 8/10
# 594/594 [==============================] - 5s 9ms/step - loss: 0.2214 - accuracy: 0.9384
# Epoch 9/10
# 594/594 [==============================] - 6s 9ms/step - loss: 0.2131 - accuracy: 0.9419
# Epoch 10/10
# 594/594 [==============================] - 5s 9ms/step - loss: 0.2124 - accuracy: 0.9412
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2914 - accuracy: 0.9133
# (pretraining) Testing accuracy from within X_reference.npy and y_reference.npy: 0.9133333563804626
# 30/30 [==============================] - 0s 4ms/step - loss: 4.1497 - accuracy: 0.5203
# Testing loss, accuracy after pretraining from X_test and y_test: 4.149662017822266 0.5203333497047424

# %% [markdown]
# Finetuning Hyperparameters and Train/Test

# %%
#finetune hyperparameters
ft_batch_size = 10
ft_epochs = 65
ft_learningRate = 1e-5


finetuned_model = ResNet.finetune(save_directory=save_directory, features=X_fine, labels=y_fine, epochs=ft_epochs, learningRate=ft_learningRate, batch_size=ft_batch_size)

loss, acc = finetuned_model.evaluate(X_test, y_test, batch_size=ft_batch_size, verbose=verbose)
print("Pretrained accuracy: ", pre_acc)
print("Fintuned accuracy: ", acc)
# Out:
# Model: "resnet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 1000, 1)]    0
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 500, 64)      320         input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 500, 64)      256         conv1d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 500, 64)      0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 500, 64)      256         activation_6[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 500, 64)      0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 500, 100)     6400        activation_7[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 500, 100)     0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 500, 100)     6400        activation_6[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 500, 100)     0           dropout_2[0][0]
#                                                                  conv1d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 500, 100)     400         add_2[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 500, 100)     0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_1 (AveragePoo (None, 62, 100)      0           activation_8[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 6200)         0           average_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 30)           186030      flatten_1[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 30)           0           dense_1[0][0]
# ==================================================================================================
# Total params: 200,062
# Trainable params: 199,606
# Non-trainable params: 456
# __________________________________________________________________________________________________
# Epoch 1/65
# 285/285 [==============================] - 1s 4ms/step - loss: 3.8089 - accuracy: 0.5726
# Epoch 2/65
# 285/285 [==============================] - 1s 4ms/step - loss: 2.8324 - accuracy: 0.6112
# Epoch 3/65
# 285/285 [==============================] - 1s 4ms/step - loss: 2.2315 - accuracy: 0.6386
# Epoch 4/65
# 285/285 [==============================] - 1s 4ms/step - loss: 1.8431 - accuracy: 0.6547
# Epoch 5/65
# 285/285 [==============================] - 1s 4ms/step - loss: 1.5857 - accuracy: 0.6611
# Epoch 6/65
# 285/285 [==============================] - 1s 4ms/step - loss: 1.4017 - accuracy: 0.6772
# Epoch 7/65
# 285/285 [==============================] - 1s 4ms/step - loss: 1.3007 - accuracy: 0.6888
# Epoch 8/65
# 285/285 [==============================] - 1s 4ms/step - loss: 1.2381 - accuracy: 0.7004
# Epoch 9/65
# 285/285 [==============================] - 1s 4ms/step - loss: 1.1749 - accuracy: 0.7039
# Epoch 10/65
# 285/285 [==============================] - 1s 4ms/step - loss: 1.1167 - accuracy: 0.7105
# Epoch 11/65
# 285/285 [==============================] - 1s 4ms/step - loss: 1.0691 - accuracy: 0.7225
# Epoch 12/65
# 285/285 [==============================] - 1s 4ms/step - loss: 1.0276 - accuracy: 0.7337
# Epoch 13/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.9734 - accuracy: 0.7428
# Epoch 14/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.9467 - accuracy: 0.7449
# Epoch 15/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.9227 - accuracy: 0.7481
# Epoch 16/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.8802 - accuracy: 0.7593
# Epoch 17/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.8669 - accuracy: 0.7625
# Epoch 18/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.8348 - accuracy: 0.7656
# Epoch 19/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.8140 - accuracy: 0.7768
# Epoch 20/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.7889 - accuracy: 0.7730
# Epoch 21/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.7711 - accuracy: 0.7828
# Epoch 22/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.7469 - accuracy: 0.7912
# Epoch 23/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.7298 - accuracy: 0.7912
# Epoch 24/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.7171 - accuracy: 0.7947
# Epoch 25/65
# 285/285 [==============================] - 1s 3ms/step - loss: 0.6883 - accuracy: 0.7982
# Epoch 26/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.6768 - accuracy: 0.8032
# Epoch 27/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.6611 - accuracy: 0.8074
# Epoch 28/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.6453 - accuracy: 0.8175
# Epoch 29/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.6388 - accuracy: 0.8193
# Epoch 30/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.6187 - accuracy: 0.8193
# Epoch 31/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.6130 - accuracy: 0.8214
# Epoch 32/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.5981 - accuracy: 0.8298
# Epoch 33/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.5829 - accuracy: 0.8316
# Epoch 34/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.5710 - accuracy: 0.8347
# Epoch 35/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.5664 - accuracy: 0.8365
# Epoch 36/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.5478 - accuracy: 0.8432
# Epoch 37/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.5426 - accuracy: 0.8474
# Epoch 38/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.5360 - accuracy: 0.8400
# Epoch 39/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.5283 - accuracy: 0.8453
# Epoch 40/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.5170 - accuracy: 0.8456
# Epoch 41/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.5058 - accuracy: 0.8519
# Epoch 42/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.5043 - accuracy: 0.8519
# Epoch 43/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.4948 - accuracy: 0.8537
# Epoch 44/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.4874 - accuracy: 0.8607
# Epoch 45/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.4728 - accuracy: 0.8677
# Epoch 46/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.4750 - accuracy: 0.8625
# Epoch 47/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.4685 - accuracy: 0.8604
# Epoch 48/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.4570 - accuracy: 0.8681
# Epoch 49/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.4508 - accuracy: 0.8737
# Epoch 50/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.4391 - accuracy: 0.8772
# Epoch 51/65
# 285/285 [==============================] - 1s 3ms/step - loss: 0.4386 - accuracy: 0.8751
# Epoch 52/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.4327 - accuracy: 0.8765
# Epoch 53/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.4277 - accuracy: 0.8768
# Epoch 54/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.4228 - accuracy: 0.8779
# Epoch 55/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.4102 - accuracy: 0.8821
# Epoch 56/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.4149 - accuracy: 0.8835
# Epoch 57/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.3962 - accuracy: 0.8884
# Epoch 58/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.3965 - accuracy: 0.8884
# Epoch 59/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.3867 - accuracy: 0.8944
# Epoch 60/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.3854 - accuracy: 0.8940
# Epoch 61/65
# 285/285 [==============================] - 1s 3ms/step - loss: 0.3782 - accuracy: 0.8954
# Epoch 62/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.3732 - accuracy: 0.9004
# Epoch 63/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.3709 - accuracy: 0.9014
# Epoch 64/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.3682 - accuracy: 0.9035
# Epoch 65/65
# 285/285 [==============================] - 1s 4ms/step - loss: 0.3640 - accuracy: 0.8993
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4479 - accuracy: 0.8400
# (finetuning) Testing accuracy from within X_fine and y_fine:  0.8399999737739563
# 300/300 [==============================] - 1s 2ms/step - loss: 0.6656 - accuracy: 0.8150
# Pretrained accuracy:  0.5203333497047424
# Fintuned accuracy:  0.8149999976158142

# %% [markdown]
# Todo:
# *   Create hyperparameter tuning framework
# *   Separate/clean up mounting google drive and loading files
# *   Add confusion matrix
# *   Comment code
# *   Add clinical tuning method
